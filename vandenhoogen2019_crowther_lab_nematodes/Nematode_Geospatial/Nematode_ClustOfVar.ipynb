# %% [markdown]
# # This code performs variable reduction via the ClustOfVar package in order to identify the most representative / least collinear covariates sampled from the point locations

# %% [markdown]
# ## Load the necessary libraries and the raw data

# %%
# Load the libraries without any messages
suppressMessages(library(ClustOfVar))
suppressMessages(library(tictoc))
suppressMessages(library(tidyverse))
suppressMessages(library(jsonlite))
suppressMessages(library(caret))

# Input the file path of the raw data CSV as a string
filePath = '20180706_NematodePoints_SampledPixelValues.csv'

# Inspect the data
nematodeData = read.csv(file=filePath, header=TRUE)
str(nematodeData)
# Out:
# 'data.frame':	1874 obs. of  87 variables:
#  $ system.index                       : Factor w/ 1874 levels "0000001a97eae3c6e448",..: 394 12 1324 226 1714 207 1396 969 219 1838 ...
#  $ Abs_Lat                            : num  22.4 22 21.3 21.3 21.4 ...
#  $ Annual_Mean_Radiation              : num  140 143 153 151 150 ...
#  $ Annual_Mean_Temperature            : num  18.1 19 19.7 19.5 18.9 ...
#  $ Annual_Precipitation               : num  1519 1528 1614 1619 1616 ...
#  $ Aridity_Index                      : num  10354 9590 10367 10575 10974 ...
#  $ Bacterivor                         : num  120 45 390 224 40 60 70 39 15 40 ...
#  $ Bulk_Density_15cm                  : num  1236 1283 1334 1317 1239 ...
#  $ CContent_15cm                      : num  25 27 19 17 27 16 35 19 20 23 ...
#  $ CatIonExcCap_15cm                  : num  12 9 7 7 8 8 9 9 8 8 ...
#  $ Clay_Content_15cm                  : num  34 40 37 36 35 33 38 39 43 42 ...
#  $ CoOfVar_EVI_Hetero_1km             : num  445 285 676 1020 2026 ...
#  $ Contrast_EVI_Hetero_1km            : num  76337 60339 139122 192497 738772 ...
#  $ CorFragVolPerc_15cm                : num  1 1 4 3 2 3 2 3 2 1 ...
#  $ Correlation_EVI_Hetero_1km         : num  4758 -1252 -609 2965 4760 ...
#  $ Depth_to_Bedrock                   : num  197 200 200 200 200 200 200 200 200 199 ...
#  $ Dissimilarity_EVI_Hetero_1km       : num  20280 18649 29891 34726 68948 ...
#  $ EVI                                : num  4194 4300 3446 3200 3224 ...
#  $ Entropy_EVI_Hetero_1km             : num  27038 20468 28478 29947 29486 ...
#  $ Evenness_EVI_Hetero_1km            : num  9202 9148 9056 9629 9632 ...
#  $ Fpar                               : num  59.5 57.5 47.4 45.2 44.4 ...
#  $ Fungivores                         : num  165 105 540 192 120 40 37 117 105 60 ...
#  $ Global_Biomass_IPCC                : num  301 500 500 500 604 ...
#  $ Gpp                                : num  24982 17141 16525 16595 16706 ...
#  $ Highest_Weekly_Radiation           : num  154 156 169 168 167 ...
#  $ Homogeneity_EVI_Hetero_1km         : num  4170 4451 2817 2238 1331 ...
#  $ Human_Development                  : num  39 54 38 13 21 30 33 49 23 20 ...
#  $ Isothermality                      : num  58.9 59.2 63.5 63.5 63.5 ...
#  $ Lai                                : num  23.5 19.3 13.7 12.5 12.2 ...
#  $ Lowest_Weekly_Radiation            : num  117 120 130 129 127 ...
#  $ Max_Temperature_of_Warmest_Month   : num  27.5 30.2 29.2 28.9 28.1 ...
#  $ Maximum_EVI_Hetero_1km             : num  1465 3320 972 665 598 ...
#  $ Mean_Diurnal_Range                 : num  11.2 13.8 12.5 12.4 12.1 ...
#  $ Mean_Temperature_of_Coldest_Quarter: num  14.7 15.4 16.7 16.5 16 ...
#  $ Mean_Temperature_of_Driest_Quarter : num  14.7 15.4 16.7 16.5 16 ...
#  $ Mean_Temperature_of_Warmest_Quarter: num  21 21.9 22 21.8 21.2 ...
#  $ Mean_Temperature_of_Wettest_Quarter: num  21 21.9 22 21.8 21.2 ...
#  $ Min_Temperature_of_Coldest_Month   : num  8.4 6.9 9.5 9.4 9 ...
#  $ NDVI                               : num  7121 6886 5559 5509 5236 ...
#  $ Nadir_Reflectance_Band1            : num  501 589 901 854 864 ...
#  $ Nadir_Reflectance_Band2            : num  3154 3142 2912 2719 2779 ...
#  $ Nadir_Reflectance_Band3            : num  277 310 453 423 446 ...
#  $ Nadir_Reflectance_Band4            : num  623 665 872 809 832 ...
#  $ Nadir_Reflectance_Band5            : num  3379 3637 3583 3434 3444 ...
#  $ Nadir_Reflectance_Band6            : num  2206 2550 2879 2764 2786 ...
#  $ Nadir_Reflectance_Band7            : num  999 1201 1657 1516 1543 ...
#  $ Npp                                : num  14420 10273 10312 10420 10481 ...
#  $ Omnivores                          : num  30 30 300 64 30 20 35 40 15 0 ...
#  $ OrgCStockTHa_0to15cm               : num  34 34 24 23 32 21 35 24 25 32 ...
#  $ PET                                : num  1467 1561 1525 1512 1477 ...
#  $ Pixel_Lat                          : num  -22.4 -22 -21.3 -21.3 -21.4 ...
#  $ Pixel_Long                         : num  -44.7 -44.9 -44.7 -44.7 -44.7 ...
#  $ Plant_feed                         : num  125 75 270 96 255 20 175 78 650 220 ...
#  $ Population_Density                 : num  8.14 4.81 2.08 3.45 1.51 ...
#  $ Precipitation_Seasonality          : num  74.9 77.3 81.2 81.2 80.6 ...
#  $ Precipitation_of_Coldest_Quarter   : num  81 71 81 82 80 77 77 74 84 86 ...
#  $ Precipitation_of_Driest_Month      : num  23 19 19 18 18 18 17 17 21 20 ...
#  $ Precipitation_of_Driest_Quarter    : num  81 71 65 65 64 60 62 60 68 70 ...
#  $ Precipitation_of_Warmest_Quarter   : num  685 790 695 697 833 822 821 794 801 818 ...
#  $ Precipitation_of_Wettest_Month     : num  269 287 329 330 325 318 316 304 309 317 ...
#  $ Precipitation_of_Wettest_Quarter   : num  769 790 835 837 833 822 821 794 801 818 ...
#  $ PredProb_of_R_Horizon              : num  11 15 6 7 9 6 11 10 9 17 ...
#  $ Predators                          : num  42 30 150 60 25 0 70 0 5 0 ...
#  $ Radiation_Seasonality              : num  0.0788 0.0782 0.0721 0.0725 0.0747 ...
#  $ Radiation_of_Coldest_Quarter       : num  126 127 138 137 135 ...
#  $ Radiation_of_Driest_Quarter        : num  126 129 140 140 138 ...
#  $ Radiation_of_Warmest_Quarter       : num  150 153 162 161 160 ...
#  $ Radiation_of_Wettest_Quarter       : num  149 151 159 158 157 ...
#  $ Range_EVI_Hetero_1km               : num  924 595 908 1479 2481 ...
#  $ Sand_Content_15cm                  : num  50 41 47 48 48 51 44 44 40 41 ...
#  $ Shannon_Index_1km                  : num  19312 16828 20342 23768 23808 ...
#  $ Silt_Content_15cm                  : num  17 19 17 16 17 17 18 18 18 18 ...
#  $ Simpson_Index_1km                  : num  8293 7903 8327 8969 8973 ...
#  $ Std_EVI_Hetero_1km                 : num  275 168 276 409 862 389 344 407 537 521 ...
#  $ Temperature_Annual_Range           : num  19.1 23.3 19.7 19.5 19.1 ...
#  $ Temperature_Seasonality            : num  258 270 224 223 216 ...
#  $ Total_Numb                         : num  482 285 1650 636 470 140 391 274 792 320 ...
#  $ Unidentifi                         : num  0 0 0 0 0 0 4 0 2 0 ...
#  $ Uniformity_EVI_Hetero_1km          : num  756 1792 618 514 538 ...
#  $ Variance_EVI_Hetero_1km            : num  70497 29684 67425 136302 716117 ...
#  $ eastness                           : num  0.678 0.207 -0.169 -0.194 0.256 ...
#  $ elevation                          : num  901 976 929 987 1141 ...
#  $ hillshade                          : num  158 171 182 183 172 ...
#  $ northness                          : num  0.121 -0.0648 -0.106 -0.5757 -0.8217 ...
#  $ pHinHOX_15cm                       : num  52 53 52 52 51 51 52 52 52 52 ...
#  $ slope                              : num  9.74 7.34 2.93 3.1 10.04 ...
#  $ .geo                               : Factor w/ 1866 levels "{\"geodesic\":true,\"type\":\"Point\",\"coordinates\":[-0.4541739997600637,44.37085633015149]}",..: 292 295 289 286 287 288 293 294 299 300 ...

# %% [markdown]
# ### Isolate the covariate data without any of the dependent variables

# %%
# Make an independent copy of the covariate data
covariateDF = subset(nematodeData,select=-c(system.index,
                                            Bacterivor,
                                            Fungivores,
                                            Omnivores,
                                            Plant_feed,
                                            Predators,
                                            Unidentifi,
                                            Pixel_Lat,
                                            Pixel_Long,
                                            Lai,
                                            Fpar,
                                            .geo))

print('Covariate Variable Names')
print(colnames(covariateDF))
# Out:
# [1] "Covariate Variable Names"
#  [1] "Abs_Lat"                             "Annual_Mean_Radiation"
#  [3] "Annual_Mean_Temperature"             "Annual_Precipitation"
#  [5] "Aridity_Index"                       "Bulk_Density_15cm"
#  [7] "CContent_15cm"                       "CatIonExcCap_15cm"
#  [9] "Clay_Content_15cm"                   "CoOfVar_EVI_Hetero_1km"
# [11] "Contrast_EVI_Hetero_1km"             "CorFragVolPerc_15cm"
# [13] "Correlation_EVI_Hetero_1km"          "Depth_to_Bedrock"
# [15] "Dissimilarity_EVI_Hetero_1km"        "EVI"
# [17] "Entropy_EVI_Hetero_1km"              "Evenness_EVI_Hetero_1km"
# [19] "Global_Biomass_IPCC"                 "Gpp"
# [21] "Highest_Weekly_Radiation"            "Homogeneity_EVI_Hetero_1km"
# [23] "Human_Development"                   "Isothermality"
# [25] "Lowest_Weekly_Radiation"             "Max_Temperature_of_Warmest_Month"
# [27] "Maximum_EVI_Hetero_1km"              "Mean_Diurnal_Range"
# [29] "Mean_Temperature_of_Coldest_Quarter" "Mean_Temperature_of_Driest_Quarter"
# [31] "Mean_Temperature_of_Warmest_Quarter" "Mean_Temperature_of_Wettest_Quarter"
# [33] "Min_Temperature_of_Coldest_Month"    "NDVI"
# [35] "Nadir_Reflectance_Band1"             "Nadir_Reflectance_Band2"
# [37] "Nadir_Reflectance_Band3"             "Nadir_Reflectance_Band4"
# [39] "Nadir_Reflectance_Band5"             "Nadir_Reflectance_Band6"
# [41] "Nadir_Reflectance_Band7"             "Npp"
# [43] "OrgCStockTHa_0to15cm"                "PET"
# [45] "Population_Density"                  "Precipitation_Seasonality"
# [47] "Precipitation_of_Coldest_Quarter"    "Precipitation_of_Driest_Month"
# [49] "Precipitation_of_Driest_Quarter"     "Precipitation_of_Warmest_Quarter"
# [51] "Precipitation_of_Wettest_Month"      "Precipitation_of_Wettest_Quarter"
# [53] "PredProb_of_R_Horizon"               "Radiation_Seasonality"
# [55] "Radiation_of_Coldest_Quarter"        "Radiation_of_Driest_Quarter"
# [57] "Radiation_of_Warmest_Quarter"        "Radiation_of_Wettest_Quarter"
# [59] "Range_EVI_Hetero_1km"                "Sand_Content_15cm"
# [61] "Shannon_Index_1km"                   "Silt_Content_15cm"
# [63] "Simpson_Index_1km"                   "Std_EVI_Hetero_1km"
# [65] "Temperature_Annual_Range"            "Temperature_Seasonality"
# [67] "Total_Numb"                          "Uniformity_EVI_Hetero_1km"
# [69] "Variance_EVI_Hetero_1km"             "eastness"
# [71] "elevation"                           "hillshade"
# [73] "northness"                           "pHinHOX_15cm"
# [75] "slope"

# %%
# Examine the number of NA's
numberOfNAs = sapply(covariateDF, function(y) sum(length(which(is.na(y)))))
numberOfNAs = data.frame(numberOfNAs)
print(numberOfNAs)
# Out:
#                                     numberOfNAs
# Abs_Lat                                       0
# Annual_Mean_Radiation                         1
# Annual_Mean_Temperature                       0
# Annual_Precipitation                          0
# Aridity_Index                                 0
# Bulk_Density_15cm                             0
# CContent_15cm                                 0
# CatIonExcCap_15cm                             0
# Clay_Content_15cm                             0
# CoOfVar_EVI_Hetero_1km                        0
# Contrast_EVI_Hetero_1km                       0
# CorFragVolPerc_15cm                           0
# Correlation_EVI_Hetero_1km                    0
# Depth_to_Bedrock                              0
# Dissimilarity_EVI_Hetero_1km                  0
# EVI                                           0
# Entropy_EVI_Hetero_1km                        0
# Evenness_EVI_Hetero_1km                       0
# Global_Biomass_IPCC                           0
# Gpp                                           6
# Highest_Weekly_Radiation                      1
# Homogeneity_EVI_Hetero_1km                    0
# Human_Development                             0
# Isothermality                                 0
# Lowest_Weekly_Radiation                       1
# Max_Temperature_of_Warmest_Month              0
# Maximum_EVI_Hetero_1km                        0
# Mean_Diurnal_Range                            0
# Mean_Temperature_of_Coldest_Quarter           0
# Mean_Temperature_of_Driest_Quarter            0
# Mean_Temperature_of_Warmest_Quarter           0
# Mean_Temperature_of_Wettest_Quarter           0
# Min_Temperature_of_Coldest_Month              0
# NDVI                                          0
# Nadir_Reflectance_Band1                       0
# Nadir_Reflectance_Band2                       0
# Nadir_Reflectance_Band3                       0
# Nadir_Reflectance_Band4                       0
# Nadir_Reflectance_Band5                       0
# Nadir_Reflectance_Band6                       0
# Nadir_Reflectance_Band7                       0
# Npp                                           6
# OrgCStockTHa_0to15cm                          0
# PET                                           0
# Population_Density                            0
# Precipitation_Seasonality                     0
# Precipitation_of_Coldest_Quarter              0
# Precipitation_of_Driest_Month                 0
# Precipitation_of_Driest_Quarter               0
# Precipitation_of_Warmest_Quarter              0
# Precipitation_of_Wettest_Month                0
# Precipitation_of_Wettest_Quarter              0
# PredProb_of_R_Horizon                         0
# Radiation_Seasonality                         1
# Radiation_of_Coldest_Quarter                  1
# Radiation_of_Driest_Quarter                   1
# Radiation_of_Warmest_Quarter                  1
# Radiation_of_Wettest_Quarter                  1
# Range_EVI_Hetero_1km                          0
# Sand_Content_15cm                             0
# Shannon_Index_1km                             0
# Silt_Content_15cm                             0
# Simpson_Index_1km                             0
# Std_EVI_Hetero_1km                            0
# Temperature_Annual_Range                      0
# Temperature_Seasonality                       0
# Total_Numb                                    0
# Uniformity_EVI_Hetero_1km                     0
# Variance_EVI_Hetero_1km                       0
# eastness                                      0
# elevation                                     0
# hillshade                                     0
# northness                                     0
# pHinHOX_15cm                                  0
# slope                                         0

# %%
# Examine how many points contain NA values
pointsWithNAs = covariateDF[!complete.cases(covariateDF),]
dim(pointsWithNAs)
# Out:
# [1]  7 75

# %%
# Make a dataset with only complete data
completeData = covariateDF[complete.cases(covariateDF),]
dim(completeData)
# Out:
# [1] 1867   75

# %% [markdown]
# ### Discern how the variables trend and choose the top variables from each cluster (specifying multiple numbers of clusters to test)

# %%
# Subset the covariate data for clustering
dataToCluster = subset(completeData,select=-c(Total_Numb))

# %%
# Examine the dimensions of the data to cluster
dim(dataToCluster)
# Out:
# [1] 1867   74

# %%
tic()

# Run the clustering function and plot the variables
tree = hclustvar(X.quanti=dataToCluster)
plot(tree)

toc()
# Out:
# 4.657 sec elapsed
# Plot with title “Cluster Dendrogram”

# %%
# Enter desired number of clusters to generate (in a vector)
numOfClusters = c(5,10,15,20,25)

# %%
# Prep an empy list to store the variables from the clustering
emptyVarsList = list()


# Loop the clustering across the desired number of clusters
for (nC in numOfClusters){
    
    # Set the random number seed
    set.seed(42)

    # Examine the top variables in each cluster
    part = cutreevar(tree,nC)

    # Instantiate an empty list in which to store the variables
    midVariableList = c()

    # Extract only the names of the variables (i.e., unlist the values in their parent data structure)
    namesListWithNulls = lapply(part$var,rownames)
    namesListWithoutNulls = Filter(Negate(function(x) is.null(unlist(x))), namesListWithNulls)

    # Ascertain the top variables from the KMeans Clustering
    # and store it in a list
    for (j in c(1:length(namesListWithoutNulls))){
        midVariableList[j] = namesListWithoutNulls[[j]][1]
    }

    # Prep the variable list for input into the model calls
    varsToInclude = list((midVariableList))
    emptyVarsList[match(nC,numOfClusters)] = varsToInclude

    }
print(emptyVarsList)
# Out:
# [[1]]
# [1] "Lowest_Weekly_Radiation"          "Min_Temperature_of_Coldest_Month"
# [3] "Nadir_Reflectance_Band7"          "Std_EVI_Hetero_1km"
# [5] "Simpson_Index_1km"
#
# [[2]]
#  [1] "Lowest_Weekly_Radiation"          "Min_Temperature_of_Coldest_Month"
#  [3] "Precipitation_of_Wettest_Quarter" "Nadir_Reflectance_Band7"
#  [5] "Sand_Content_15cm"                "Std_EVI_Hetero_1km"
#  [7] "PredProb_of_R_Horizon"            "Nadir_Reflectance_Band1"
#  [9] "Simpson_Index_1km"                "hillshade"
#
# [[3]]
#  [1] "Lowest_Weekly_Radiation"          "Min_Temperature_of_Coldest_Month"
#  [3] "Precipitation_of_Wettest_Quarter" "Precipitation_of_Driest_Quarter"
#  [5] "OrgCStockTHa_0to15cm"             "Sand_Content_15cm"
#  [7] "Std_EVI_Hetero_1km"               "PredProb_of_R_Horizon"
#  [9] "Nadir_Reflectance_Band1"          "Simpson_Index_1km"
# [11] "Human_Development"                "Radiation_of_Warmest_Quarter"
# [13] "Nadir_Reflectance_Band7"          "Nadir_Reflectance_Band5"
# [15] "hillshade"
#
# [[4]]
#  [1] "Lowest_Weekly_Radiation"          "Min_Temperature_of_Coldest_Month"
#  [3] "Precipitation_of_Wettest_Quarter" "Precipitation_of_Driest_Quarter"
#  [5] "OrgCStockTHa_0to15cm"             "Sand_Content_15cm"
#  [7] "Std_EVI_Hetero_1km"               "PredProb_of_R_Horizon"
#  [9] "NDVI"                             "Simpson_Index_1km"
# [11] "Global_Biomass_IPCC"              "Radiation_of_Warmest_Quarter"
# [13] "Nadir_Reflectance_Band7"          "Nadir_Reflectance_Band4"
# [15] "Nadir_Reflectance_Band5"          "hillshade"
#
# [[5]]
#  [1] "Lowest_Weekly_Radiation"          "Min_Temperature_of_Coldest_Month"
#  [3] "Precipitation_of_Wettest_Quarter" "Precipitation_of_Driest_Quarter"
#  [5] "OrgCStockTHa_0to15cm"             "Std_EVI_Hetero_1km"
#  [7] "slope"                            "PredProb_of_R_Horizon"
#  [9] "NDVI"                             "Simpson_Index_1km"
# [11] "Radiation_of_Warmest_Quarter"     "Precipitation_Seasonality"
# [13] "Nadir_Reflectance_Band4"          "Nadir_Reflectance_Band5"
# [15] "Nadir_Reflectance_Band7"          "Silt_Content_15cm"
# [17] "hillshade"

# %%
# Export the results to a JSON file or a CSV
variableDataFrame = as.data.frame(cbind(numOfClusters,emptyVarsList))
variableDataFrame
# Out:
#   numOfClusters
# 1 5
# 2 10
# 3 15
# 4 20
# 5 25
#   emptyVarsList
# 1 Lowest_Weekly_Radiation         , Min_Temperature_of_Coldest_Month, Nadir_Reflectance_Band7         , Std_EVI_Hetero_1km              , Simpson_Index_1km
# 2 Lowest_Weekly_Radiation         , Min_Temperature_of_Coldest_Month, Precipitation_of_Wettest_Quarter, Nadir_Reflectance_Band7         , Sand_Content_15cm               , Std_EVI_Hetero_1km              , PredProb_of_R_Horizon           , Nadir_Reflectance_Band1         , Simpson_Index_1km               , hillshade
# 3 Lowest_Weekly_Radiation         , Min_Temperature_of_Coldest_Month, Precipitation_of_Wettest_Quarter, Precipitation_of_Driest_Quarter , OrgCStockTHa_0to15cm            , Sand_Content_15cm               , Std_EVI_Hetero_1km              , PredProb_of_R_Horizon           , Nadir_Reflectance_Band1         , Simpson_Index_1km               , Human_Development               , Radiation_of_Warmest_Quarter    , Nadir_Reflectance_Band7         , Nadir_Reflectance_Band5         , hillshade
# 4 Lowest_Weekly_Radiation         , Min_Temperature_of_Coldest_Month, Precipitation_of_Wettest_Quarter, Precipitation_of_Driest_Quarter , OrgCStockTHa_0to15cm            , Sand_Content_15cm               , Std_EVI_Hetero_1km              , PredProb_of_R_Horizon           , NDVI                            , Simpson_Index_1km               , Global_Biomass_IPCC             , Radiation_of_Warmest_Quarter    , Nadir_Reflectance_Band7         , Nadir_Reflectance_Band4         , Nadir_Reflectance_Band5         , hillshade
# 5 Lowest_Weekly_Radiation         , Min_Temperature_of_Coldest_Month, Precipitation_of_Wettest_Quarter, Precipitation_of_Driest_Quarter , OrgCStockTHa_0to15cm            , Std_EVI_Hetero_1km              , slope                           , PredProb_of_R_Horizon           , NDVI                            , Simpson_Index_1km               , Radiation_of_Warmest_Quarter    , Precipitation_Seasonality       , Nadir_Reflectance_Band4         , Nadir_Reflectance_Band5         , Nadir_Reflectance_Band7         , Silt_Content_15cm               , hillshade

# %%
write_json(variableDataFrame,'20180706_Nematode_Variables_Clustered.json')
